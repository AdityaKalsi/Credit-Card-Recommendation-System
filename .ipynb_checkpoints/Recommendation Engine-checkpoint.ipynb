# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import numpy as np
# Out:
# C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\sklearn\utils\_param_validation.py:11: UserWarning: A NumPy version >=1.22.4 and <2.3.0 is required for this version of SciPy (detected version 2.3.0)
#   from scipy.sparse import csr_matrix, issparse
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\traitlets\config\application.py", line 992, in launch_instance
#     app.start()
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\ipykernel\kernelapp.py", line 701, in start
#     self.io_loop.start()
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\tornado\platform\asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\asyncio\windows_events.py", line 321, in run_forever
#     super().run_forever()
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\ipykernel\kernelbase.py", line 534, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\ipykernel\kernelbase.py", line 523, in process_one
#     await dispatch(*args)
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\ipykernel\kernelbase.py", line 429, in dispatch_shell
#     await result
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\ipykernel\kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\ipykernel\ipkernel.py", line 429, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\IPython\core\interactiveshell.py", line 3051, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\IPython\core\interactiveshell.py", line 3106, in _run_cell
#     result = runner(coro)
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\IPython\core\interactiveshell.py", line 3311, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\IPython\core\interactiveshell.py", line 3493, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\IPython\core\interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Aditya kalsi\AppData\Local\Temp\ipykernel_12680\3231997254.py", line 3, in <module>
#     import pandas as pd
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\pandas\__init__.py", line 39, in <module>
#     from pandas.compat import (
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\pandas\compat\__init__.py", line 27, in <module>
#     from pandas.compat.pyarrow import (
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\pandas\compat\pyarrow.py", line 8, in <module>
#     import pyarrow as pa
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\pyarrow\__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\traitlets\config\application.py", line 992, in launch_instance
#     app.start()
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\ipykernel\kernelapp.py", line 701, in start
#     self.io_loop.start()
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\tornado\platform\asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\asyncio\windows_events.py", line 321, in run_forever
#     super().run_forever()
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\ipykernel\kernelbase.py", line 534, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\ipykernel\kernelbase.py", line 523, in process_one
#     await dispatch(*args)
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\ipykernel\kernelbase.py", line 429, in dispatch_shell
#     await result
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\ipykernel\kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\ipykernel\ipkernel.py", line 429, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\IPython\core\interactiveshell.py", line 3051, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\IPython\core\interactiveshell.py", line 3106, in _run_cell
#     result = runner(coro)
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\IPython\core\interactiveshell.py", line 3311, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\IPython\core\interactiveshell.py", line 3493, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\IPython\core\interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Aditya kalsi\AppData\Local\Temp\ipykernel_12680\3231997254.py", line 3, in <module>
#     import pandas as pd
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\pandas\__init__.py", line 62, in <module>
#     from pandas.core.api import (
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\pandas\core\api.py", line 9, in <module>
#     from pandas.core.dtypes.dtypes import (
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\pandas\core\dtypes\dtypes.py", line 24, in <module>
#     from pandas._libs import (
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\pyarrow\__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\traitlets\config\application.py", line 992, in launch_instance
#     app.start()
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\ipykernel\kernelapp.py", line 701, in start
#     self.io_loop.start()
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\tornado\platform\asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\asyncio\windows_events.py", line 321, in run_forever
#     super().run_forever()
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\ipykernel\kernelbase.py", line 534, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\ipykernel\kernelbase.py", line 523, in process_one
#     await dispatch(*args)
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\ipykernel\kernelbase.py", line 429, in dispatch_shell
#     await result
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\ipykernel\kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\ipykernel\ipkernel.py", line 429, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\IPython\core\interactiveshell.py", line 3051, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\IPython\core\interactiveshell.py", line 3106, in _run_cell
#     result = runner(coro)
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\IPython\core\interactiveshell.py", line 3311, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\IPython\core\interactiveshell.py", line 3493, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\IPython\core\interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Aditya kalsi\AppData\Local\Temp\ipykernel_12680\3231997254.py", line 3, in <module>
#     import pandas as pd
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\pandas\__init__.py", line 62, in <module>
#     from pandas.core.api import (
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\pandas\core\api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\pandas\core\arrays\__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\pandas\core\arrays\arrow\__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\pandas\core\arrays\arrow\array.py", line 50, in <module>
#     from pandas.core import (
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\pandas\core\ops\__init__.py", line 8, in <module>
#     from pandas.core.ops.array_ops import (
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\pandas\core\ops\array_ops.py", line 56, in <module>
#     from pandas.core.computation import expressions
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\pandas\core\computation\expressions.py", line 21, in <module>
#     from pandas.core.computation.check import NUMEXPR_INSTALLED
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\pandas\core\computation\check.py", line 5, in <module>
#     ne = import_optional_dependency("numexpr", errors="warn")
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\pandas\compat\_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\numexpr\__init__.py", line 24, in <module>
#     from numexpr.interpreter import MAX_THREADS, use_vml, __BLOCK_SIZE1__
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\traitlets\config\application.py", line 992, in launch_instance
#     app.start()
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\ipykernel\kernelapp.py", line 701, in start
#     self.io_loop.start()
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\tornado\platform\asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\asyncio\windows_events.py", line 321, in run_forever
#     super().run_forever()
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\ipykernel\kernelbase.py", line 534, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\ipykernel\kernelbase.py", line 523, in process_one
#     await dispatch(*args)
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\ipykernel\kernelbase.py", line 429, in dispatch_shell
#     await result
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\ipykernel\kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\ipykernel\ipkernel.py", line 429, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\IPython\core\interactiveshell.py", line 3051, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\IPython\core\interactiveshell.py", line 3106, in _run_cell
#     result = runner(coro)
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\IPython\core\interactiveshell.py", line 3311, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\IPython\core\interactiveshell.py", line 3493, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\IPython\core\interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Aditya kalsi\AppData\Local\Temp\ipykernel_12680\3231997254.py", line 3, in <module>
#     import pandas as pd
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\pandas\__init__.py", line 62, in <module>
#     from pandas.core.api import (
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\pandas\core\api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\pandas\core\arrays\__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\pandas\core\arrays\arrow\__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\pandas\core\arrays\arrow\array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\pandas\core\arrays\masked.py", line 60, in <module>
#     from pandas.core import (
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\pandas\core\nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\pandas\compat\_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "C:\Users\Aditya kalsi\aditya139\adi\Lib\site-packages\bottleneck\__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found

# %%
df = pd.read_csv('final_card_data.csv')

# %%
df.iloc[0]
# Out:
# Card Name                                        Cashback SBI Credit Card
# Pros                    Decent 5% cashback on online and 1% cashback o...
# Cons                    There are several categories excluded from 1% ...
# Card Page Link          https://cardinsider.com/sbi-card/cashback-sbi-...
# Apply Link                         https://cardinsider.com/go/sbicashback
# Image URL               data:image/svg+xml,%3Csvg%20xmlns='http://www....
# Annual Fee                                           ['Shopping', 'Food']
# Best For                                              Reward TypeCashback
# USP                                                                   NaN
# Joining Fees                                                   ₹999 + GST
# Renewal Fees                                                   ₹999 + GST
# Rewards and Benefits    {'Movie & Dining': 'N/A', 'Rewards Rate': '5% ...
# Name: 0, dtype: object

# %%
df['Rewards and Benefits'][1]
# Out:
# "{'Movie & Dining': '10% Cashback on Swiggy app including food orders, Instamart, Dineout, and more', 'Rewards Rate': '10% Cashback across Swiggy app, 5% Cashback on online spends, 1% Cashback on other categories', 'Reward Redemption': 'Cashback Against Credit Card Statement', 'Travel': 'Upto 5% cashback on merchants like Uber and Ola', 'Domestic Lounge Access': 'NA', 'International Lounge Access': 'NA', 'Golf': '12 Free Golf Lessons, 4 Free Rounds of Green Fees, and 50% Off on Golf Services', 'Insurance Benefits': 'NA'}"

# %%
import ast

# Convert string to dictionary
df['parsed_rewards'] = df['Rewards and Benefits'].apply(lambda x: ast.literal_eval(x))

# %%
df['parsed_rewards'][0]
# Out:
# {'Movie & Dining': 'N/A',
#  'Rewards Rate': '5% Cashback for Online Spends. 1% Cashback for Offline Spends. Maximum Cashback of ₹5,000 in a Statement Cycle',
#  'Reward Redemption': 'Cashback earned with the card will be automatically credited to next month’s statement.',
#  'Travel': 'N/A',
#  'Domestic Lounge Access': 'N/A',
#  'International Lounge Access': 'N/A',
#  'Golf': 'N/A',
#  'Insurance Benefits': 'N/A'}

# %%
# Apply transformation to each row
df['parsed_rewards'] = df['parsed_rewards'].apply(
    lambda reward_dict: {k: v for k, v in reward_dict.items() if v != 'N/A'}
)

# %%
df['parsed_rewards'][0]
# Out:
# {'Rewards Rate': '5% Cashback for Online Spends. 1% Cashback for Offline Spends. Maximum Cashback of ₹5,000 in a Statement Cycle',
#  'Reward Redemption': 'Cashback earned with the card will be automatically credited to next month’s statement.'}

# %%
def rewards_to_text(rewards_dict):
    return " ".join([f"{k}: {v}" for k, v in rewards_dict.items()])

df['benefits_text'] = df['parsed_rewards'].apply(rewards_to_text)

# %%
df['benefits_text'][1]
# Out:
# 'Movie & Dining: 10% Cashback on Swiggy app including food orders, Instamart, Dineout, and more Rewards Rate: 10% Cashback across Swiggy app, 5% Cashback on online spends, 1% Cashback on other categories Reward Redemption: Cashback Against Credit Card Statement Travel: Upto 5% cashback on merchants like Uber and Ola Domestic Lounge Access: NA International Lounge Access: NA Golf: 12 Free Golf Lessons, 4 Free Rounds of Green Fees, and 50% Off on Golf Services Insurance Benefits: NA'

# %%
df
# Out:
#                                            Card Name  \
# 0                           Cashback SBI Credit Card
# 1                       Swiggy HDFC Bank Credit Card
# 2                    HDFC Bank Millennia Credit Card
# 3                  Amazon Pay ICICI Bank Credit Card
# 4                     Flipkart Axis Bank Credit Card
# 5   American Express Membership Rewards® Credit Card
# 6            IDFC First Bank Ashva Metal Credit Card
# 7            Tata Neu Infinity HDFC Bank Credit Card
# 8                       Airtel Axis Bank Credit Card
# 9                          Axis Bank Neo Credit Card
# 10                           AU Bank LIT Credit Card
# 11                       IndusInd Legend Credit Card
# 12                       Axis Bank Atlas Credit Card
# 13                     IDFC FIRST Select Credit Card
# 14                       BPCL SBI Octane Credit Card
# 15      American Express Platinum Travel Credit Card
# 16               HDFC Bank INFINIA Metal Credit Card
# 17                         BOBCARD Tiara Credit Card
# 18                 MakeMyTrip ICICI Bank Credit Card
# 19    HSBC Live+ Credit Card – Cashback on Groceries
#
#                                                  Pros  \
# 0   Decent 5% cashback on online and 1% cashback o...
# 1   Get 10% cashback on all your Swiggy food deliv...
# 2   Get high 5% cashback on partner merchants like...
# 3   This card is most useful to Amazon loyalist wh...
# 4   Flipkart Axis Bank Credit Card offers a very g...
# 5   Membership Reward Points do not expire. There ...
# 6   From domestic airports to international ones a...
# 7   10% cashback on the Tata Neu app. Low foreign ...
# 8   You would get 25% exclusive cashback on Airtel...
# 9   Get 10% off while booking movies with BookMySh...
# 10                                                NaN
# 11  This is a lifetime free credit, which comes wi...
# 12  You will receive 2,500 EDGE Miles as a welcome...
# 13  This is a lifetime free credit card without an...
# 14  Welcome benefit of 6,000 Reward Points worth R...
# 15  One can indiscriminately spend with this card ...
# 16  Unlimited lounge access at domestic and select...
# 17  Although this card has a Forex markup charge o...
# 18                                                NaN
# 19                                                NaN
#
#                                                  Cons  \
# 0   There are several categories excluded from 1% ...
# 1   Although this card offers great benefits on fo...
# 2   You earn a low 1% cash back on offline/online ...
# 3   This card is mainly for shopping with Amazon i...
# 4   Flipkart Axis Bank Credit Card is definitely o...
# 5   This card is exclusively available to resident...
# 6   To fully take advantage of this card, you woul...
# 7   NeuCoins expire after a period of one year. Th...
# 8   With the Airtel Axis Bank Credit Card, you hav...
# 9   There are no insurance benefits provided with ...
# 10                                                NaN
# 11  There is only one BOGO offer per month with th...
# 12  The Axis Bank Atlas Credit Card doesn’t includ...
# 13  There isn’t any complimentary international lo...
# 14  There is a reward redemption fee of Rs. 99. No...
# 15  Although this card offers a good reward rate, ...
# 16  Infinia Credit Card is a highly rewarding card...
# 17  The Tiara Credit Card offers two attractive be...
# 18                                                NaN
# 19                                                NaN
#
#                                        Card Page Link  \
# 0   https://cardinsider.com/sbi-card/cashback-sbi-...
# 1   https://cardinsider.com/hdfc-bank/swiggy-hdfc-...
# 2   https://cardinsider.com/hdfc-bank/hdfc-bank-mi...
# 3   https://cardinsider.com/icici-bank/amazon-pay-...
# 4   https://cardinsider.com/axis-bank/flipkart-axi...
# 5   https://cardinsider.com/american-express/ameri...
# 6   https://cardinsider.com/idfc-first-bank/ashva-...
# 7   https://cardinsider.com/hdfc-bank/tata-neu-inf...
# 8   https://cardinsider.com/axis-bank/airtel-axis-...
# 9   https://cardinsider.com/axis-bank/axis-bank-ne...
# 10   https://cardinsider.com/au-bank/lit-credit-card/
# 11  https://cardinsider.com/indusind-bank/indusind...
# 12  https://cardinsider.com/axis-bank/axis-bank-at...
# 13  https://cardinsider.com/idfc-first-bank/idfc-f...
# 14  https://cardinsider.com/sbi-card/bpcl-sbi-card...
# 15  https://cardinsider.com/american-express/ameri...
# 16  https://cardinsider.com/hdfc-bank/hdfc-bank-in...
# 17  https://cardinsider.com/bank-of-baroda/bobcard...
# 18  https://cardinsider.com/icici-bank/makemytrip-...
# 19  https://cardinsider.com/hsbc-bank/hsbc-cashbac...
#
#                                   Apply Link  \
# 0     https://cardinsider.com/go/sbicashback
# 1      https://cardinsider.com/go/hdfcswiggy
# 2        https://cardinsider.com/go/hdfcbank
# 3     https://cardinsider.com/go/iciciamazon
# 4        https://cardinsider.com/go/axisbank
# 5                                        NaN
# 6      https://cardinsider.com/go/idfc-ashva
# 7     https://cardinsider.com/go/hdfctataneu
# 8        https://cardinsider.com/go/axisbank
# 9        https://cardinsider.com/go/axisbank
# 10         https://cardinsider.com/go/aubank
# 11       https://cardinsider.com/go/indusind
# 12       https://cardinsider.com/go/axisbank
# 13       https://cardinsider.com/go/idfcbank
# 14  https://cardinsider.com/go/sbibpcloctane
# 15                                       NaN
# 16       https://cardinsider.com/go/hdfcbank
# 17   https://cardinsider.com/go/bankofbaroda
# 18      https://cardinsider.com/go/icicibank
# 19           https://cardinsider.com/go/hsbc
#
#                                             Image URL  \
# 0   data:image/svg+xml,%3Csvg%20xmlns='http://www....
# 1   data:image/svg+xml,%3Csvg%20xmlns='http://www....
# 2   data:image/svg+xml,%3Csvg%20xmlns='http://www....
# 3   data:image/svg+xml,%3Csvg%20xmlns='http://www....
# 4   data:image/svg+xml,%3Csvg%20xmlns='http://www....
# 5   data:image/svg+xml,%3Csvg%20xmlns='http://www....
# 6   data:image/svg+xml,%3Csvg%20xmlns='http://www....
# 7   data:image/svg+xml,%3Csvg%20xmlns='http://www....
# 8   data:image/svg+xml,%3Csvg%20xmlns='http://www....
# 9   data:image/svg+xml,%3Csvg%20xmlns='http://www....
# 10  data:image/svg+xml,%3Csvg%20xmlns='http://www....
# 11  data:image/svg+xml,%3Csvg%20xmlns='http://www....
# 12  data:image/svg+xml,%3Csvg%20xmlns='http://www....
# 13  data:image/svg+xml,%3Csvg%20xmlns='http://www....
# 14  data:image/svg+xml,%3Csvg%20xmlns='http://www....
# 15  data:image/svg+xml,%3Csvg%20xmlns='http://www....
# 16  data:image/svg+xml,%3Csvg%20xmlns='http://www....
# 17  data:image/svg+xml,%3Csvg%20xmlns='http://www....
# 18  data:image/svg+xml,%3Csvg%20xmlns='http://www....
# 19  data:image/svg+xml,%3Csvg%20xmlns='http://www....
#
#                                            Annual Fee  \
# 0                                ['Shopping', 'Food']
# 1                                  ['Dining', 'Food']
# 2                                        ['Shopping']
# 3                                        ['Shopping']
# 4                                        ['Shopping']
# 5                                        ['Shopping']
# 6                              ['Travel', 'Shopping']
# 7                              ['Travel', 'Shopping']
# 8          ['Travel', 'Food', 'Utility Bill Payment']
# 9                                ['Shopping', 'Food']
# 10  ['Movies', 'Travel', 'Dining', 'Fuel', 'Shoppi...
# 11                                       ['Shopping']
# 12                                         ['Travel']
# 13                             ['Travel', 'Shopping']
# 14                         ['Travel', 'Fuel', 'Food']
# 15                             ['Travel', 'Shopping']
# 16                   ['Travel', 'Dining', 'Shopping']
# 17                     ['Travel', 'Shopping', 'Food']
# 18                                         ['Travel']
# 19                               ['Shopping', 'Food']
#
#                     Best For  \
# 0        Reward TypeCashback
# 1        Reward TypeCashback
# 2        Reward TypeCashback
# 3        Reward TypeCashback
# 4        Reward TypeCashback
# 5   Reward TypeReward Points
# 6   Reward TypeReward Points
# 7        Reward TypeNeuCoins
# 8        Reward TypeCashback
# 9   Reward TypeReward Points
# 10  Reward TypeReward Points
# 11  Reward TypeReward Points
# 12  Reward TypeReward Points
# 13  Reward TypeReward Points
# 14  Reward TypeReward Points
# 15  Reward TypeReward Points
# 16  Reward TypeReward Points
# 17  Reward TypeReward Points
# 18  Reward TypeReward Points
# 19       Reward TypeCashback
#
#                                                   USP     Joining Fees  \
# 0                                                 NaN       ₹999 + GST
# 1         Complimentary 3-Month Swiggy One Membership       ₹500 + GST
# 2                                    1,000 CashPoints     ₹1,000 + GST
# 3   Cashback and Discounts Up to ₹2,500 (Both for ...    Lifetime Free
# 4   Introductory Benefits Worth Rs. 600 on Card Is...    Rs. 500 + GST
# 5   4,000 Bonus Membership RPs can be availed on S...     ₹1,000 + GST
# 6   ₹2,000 Cashback on Making Four Transactions of...     ₹2,999 + GST
# 7                      1,499 NeuCoins on Tata Neu App     ₹1,499 + GST
# 8                        Amazon Voucher Worth Rs. 500       ₹500 + GST
# 9   100% Cashback Up to ₹300 on First Utility Bill...              Nil
# 10                                                NaN              Nil
# 11                                                NaN              Nil
# 12  2,500 Edge Miles on Completing 1 Transaction W...  Rs. 5,000 + GST
# 13  Vouchers worth ₹500 on spends of ₹5,000 within...              Nil
# 14             6,000 Bonus Reward Points Worth ₹1,500  Rs. 1,499 + GST
# 15                   10,000 Membership Rewards Points     ₹5,000 + GST
# 16  Welcome bonus of 12,500 Reward Points and comp...    ₹12,500 + GST
# 17  Free Swiggy One (3 Months), FitPass Pro, Amazo...     ₹2,499 + GST
# 18  ₹1,000 MMT Voucher and MMTBLACK Gold Tier Memb...       ₹999 + GST
# 19  ₹1,000 Cashback on Spending ₹20,000 in the Fir...    Rs. 999 + GST
#
#        Renewal Fees                               Rewards and Benefits  \
# 0        ₹999 + GST  {'Movie & Dining': 'N/A', 'Rewards Rate': '5% ...
# 1        ₹500 + GST  {'Movie & Dining': '10% Cashback on Swiggy app...
# 2      ₹1,000 + GST  {'Movie & Dining': 'Flat ₹200 Discount on Swig...
# 3     Lifetime Free  {'Movie & Dining': 'A minimum of 15% discount ...
# 4     Rs. 500 + GST  {'Movie & Dining': '15% Up to ₹500 Off at Part...
# 5      ₹4,500 + GST  {'Movie & Dining': 'Get special dining discoun...
# 6      ₹2,999 + GST  {'Movie & Dining': 'BOGO on Movie Ticket Booki...
# 7      ₹1,499 + GST  {'Movie & Dining': 'N/A', 'Rewards Rate': 'Up ...
# 8        ₹500 + GST  {'Movie & Dining': '15% Off Up to ₹500 Via Eaz...
# 9               Nil  {'Movie & Dining': 'You get 10% off on booking...
# 10              Nil  {'Movie & Dining': '3 Months of Complimentary ...
# 11              Nil  {'Movie & Dining': 'BOGO on 1 movie ticket eve...
# 12  Rs. 5,000 + GST  {'Movie & Dining': 'Discounts of up to 25% up ...
# 13              Nil  {'Movie & Dining': '“Buy One Get One” offer on...
# 14  Rs. 1,499 + GST  {'Movie & Dining': 'Accelerated 10 Reward Poin...
# 15     ₹5,000 + GST  {'Movie & Dining': '20% Discount at Select Res...
# 16    ₹12,500 + GST  {'Movie & Dining': '1 + 1 Complimentary Buffet...
# 17     ₹2,499 + GST  {'Movie & Dining': 'Free Swiggy One Membership...
# 18       ₹999 + GST  {'Movie & Dining': 'BOGO on Movie Ticket Booki...
# 19    Rs. 999 + GST  {'Movie & Dining': 'Buy 2 Get 1 Free offer on ...
#
#                                        parsed_rewards  \
# 0   {'Rewards Rate': '5% Cashback for Online Spend...
# 1   {'Movie & Dining': '10% Cashback on Swiggy app...
# 2   {'Movie & Dining': 'Flat ₹200 Discount on Swig...
# 3   {'Movie & Dining': 'A minimum of 15% discount ...
# 4   {'Movie & Dining': '15% Up to ₹500 Off at Part...
# 5   {'Movie & Dining': 'Get special dining discoun...
# 6   {'Movie & Dining': 'BOGO on Movie Ticket Booki...
# 7   {'Rewards Rate': 'Up to 10% NeuCoins on TataNe...
# 8   {'Movie & Dining': '15% Off Up to ₹500 Via Eaz...
# 9   {'Movie & Dining': 'You get 10% off on booking...
# 10  {'Movie & Dining': '3 Months of Complimentary ...
# 11  {'Movie & Dining': 'BOGO on 1 movie ticket eve...
# 12  {'Movie & Dining': 'Discounts of up to 25% up ...
# 13  {'Movie & Dining': '“Buy One Get One” offer on...
# 14  {'Movie & Dining': 'Accelerated 10 Reward Poin...
# 15  {'Movie & Dining': '20% Discount at Select Res...
# 16  {'Movie & Dining': '1 + 1 Complimentary Buffet...
# 17  {'Movie & Dining': 'Free Swiggy One Membership...
# 18  {'Movie & Dining': 'BOGO on Movie Ticket Booki...
# 19  {'Movie & Dining': 'Buy 2 Get 1 Free offer on ...
#
#                                         benefits_text
# 0   Rewards Rate: 5% Cashback for Online Spends. 1...
# 1   Movie & Dining: 10% Cashback on Swiggy app inc...
# 2   Movie & Dining: Flat ₹200 Discount on Swiggy D...
# 3   Movie & Dining: A minimum of 15% discount on d...
# 4   Movie & Dining: 15% Up to ₹500 Off at Partner ...
# 5   Movie & Dining: Get special dining discounts u...
# 6   Movie & Dining: BOGO on Movie Ticket Bookings ...
# 7   Rewards Rate: Up to 10% NeuCoins on TataNeu Sp...
# 8   Movie & Dining: 15% Off Up to ₹500 Via EazyDin...
# 9   Movie & Dining: You get 10% off on booking mov...
# 10  Movie & Dining: 3 Months of Complimentary Memb...
# 11  Movie & Dining: BOGO on 1 movie ticket every m...
# 12  Movie & Dining: Discounts of up to 25% up to R...
# 13  Movie & Dining: “Buy One Get One” offer on mov...
# 14  Movie & Dining: Accelerated 10 Reward Points f...
# 15  Movie & Dining: 20% Discount at Select Restaur...
# 16  Movie & Dining: 1 + 1 Complimentary Buffet at ...
# 17  Movie & Dining: Free Swiggy One Membership, Qu...
# 18  Movie & Dining: BOGO on Movie Ticket Bookings ...
# 19  Movie & Dining: Buy 2 Get 1 Free offer on movi...

# %%
import re

def clean_joining_fee(fee):
    if pd.isna(fee):
        return 0
    fee = fee.lower().strip()
    
    # Treat 'nil' or 'lifetime free' as 0
    if 'nil' in fee or 'free' in fee:
        return 0
    
    # Extract numeric part
    match = re.search(r'(\d+[,\d]*)', fee)
    if match:
        num_str = match.group(1).replace(',', '')
        return int(num_str)
    return 0  # fallback if nothing is matched

# Apply to your DataFrame
df["Joining Fees Cleaned"] = df["Joining Fees"].apply(clean_joining_fee)

# %%
df["Joining Fees Cleaned"]
# Out:
# 0       999
# 1       500
# 2      1000
# 3         0
# 4       500
# 5      1000
# 6      2999
# 7      1499
# 8       500
# 9         0
# 10        0
# 11        0
# 12     5000
# 13        0
# 14     1499
# 15     5000
# 16    12500
# 17     2499
# 18      999
# 19      999
# Name: Joining Fees Cleaned, dtype: int64

# %%
def clean_renewal_fee(fee):
    if pd.isna(fee):
        return 0
    fee = fee.lower().strip()
    
    # Handle free cases
    if 'nil' in fee or 'free' in fee:
        return 0

    # Extract numeric part
    match = re.search(r'(\d+[,\d]*)', fee)
    if match:
        num_str = match.group(1).replace(',', '')
        return int(num_str)
    return 0

# Apply to your DataFrame
df["Renewal Fees Cleaned"] = df["Renewal Fees"].apply(clean_renewal_fee)

# %%
df["Renewal Fees Cleaned"]
# Out:
# 0       999
# 1       500
# 2      1000
# 3         0
# 4       500
# 5      4500
# 6      2999
# 7      1499
# 8       500
# 9         0
# 10        0
# 11        0
# 12     5000
# 13        0
# 14     1499
# 15     5000
# 16    12500
# 17     2499
# 18      999
# 19      999
# Name: Renewal Fees Cleaned, dtype: int64

# %%
df['USP'] = df['USP'].fillna('')

# %%
df['combined_features'] = df['USP'] + ' ' + df['benefits_text']

# %%
df['combined_features'][0]
# Out:
# ' Rewards Rate: 5% Cashback for Online Spends. 1% Cashback for Offline Spends. Maximum Cashback of ₹5,000 in a Statement Cycle Reward Redemption: Cashback earned with the card will be automatically credited to next month’s statement.'

# %%
df['combined_features_list'] = df['combined_features'].apply(
    lambda x: [sentence.strip() for sentence in x.split('.') if sentence.strip()]
)

# %%
df['combined_features_list'][1]
# Out:
# ['Complimentary 3-Month Swiggy One Membership Movie & Dining: 10% Cashback on Swiggy app including food orders, Instamart, Dineout, and more Rewards Rate: 10% Cashback across Swiggy app, 5% Cashback on online spends, 1% Cashback on other categories Reward Redemption: Cashback Against Credit Card Statement Travel: Upto 5% cashback on merchants like Uber and Ola Domestic Lounge Access: NA International Lounge Access: NA Golf: 12 Free Golf Lessons, 4 Free Rounds of Green Fees, and 50% Off on Golf Services Insurance Benefits: NA']

# %%
import ast

df['Annual Fee'] = df['Annual Fee'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# %%
df['main_features'] = df['Annual Fee'] + df['combined_features_list']

# %%
df['main_features'][1]
# Out:
# ['Dining',
#  'Food',
#  'Complimentary 3-Month Swiggy One Membership Movie & Dining: 10% Cashback on Swiggy app including food orders, Instamart, Dineout, and more Rewards Rate: 10% Cashback across Swiggy app, 5% Cashback on online spends, 1% Cashback on other categories Reward Redemption: Cashback Against Credit Card Statement Travel: Upto 5% cashback on merchants like Uber and Ola Domestic Lounge Access: NA International Lounge Access: NA Golf: 12 Free Golf Lessons, 4 Free Rounds of Green Fees, and 50% Off on Golf Services Insurance Benefits: NA']

# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy in c:\users\aditya kalsi\aditya139\adi\lib\site-packages (3.8.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\aditya kalsi\aditya139\adi\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\aditya kalsi\aditya139\adi\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\aditya kalsi\aditya139\adi\lib\site-packages (from spacy) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\aditya kalsi\aditya139\adi\lib\site-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\aditya kalsi\aditya139\adi\lib\site-packages (from spacy) (3.0.10)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\aditya kalsi\aditya139\adi\lib\site-packages (from spacy) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\aditya kalsi\aditya139\adi\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\aditya kalsi\aditya139\adi\lib\site-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\aditya kalsi\aditya139\adi\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\aditya kalsi\aditya139\adi\lib\site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\aditya kalsi\aditya139\adi\lib\site-packages (from spacy) (0.16.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\aditya kalsi\aditya139\adi\lib\site-packages (from spacy) (4.66.5)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\aditya kalsi\aditya139\adi\lib\site-packages (from spacy) (2.3.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\aditya kalsi\aditya139\adi\lib\site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\aditya kalsi\aditya139\adi\lib\site-packages (from spacy) (2.9.2)
# Requirement already satisfied: jinja2 in c:\users\aditya kalsi\aditya139\adi\lib\site-packages (from spacy) (3.1.3)
# Requirement already satisfied: setuptools in c:\users\aditya kalsi\aditya139\adi\lib\site-packages (from spacy) (68.2.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\aditya kalsi\aditya139\adi\lib\site-packages (from spacy) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\aditya kalsi\aditya139\adi\lib\site-packages (from spacy) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in c:\users\aditya kalsi\aditya139\adi\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\aditya kalsi\aditya139\adi\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\aditya kalsi\aditya139\adi\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\aditya kalsi\aditya139\adi\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aditya kalsi\aditya139\adi\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aditya kalsi\aditya139\adi\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aditya kalsi\aditya139\adi\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aditya kalsi\aditya139\adi\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.8.30)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\aditya kalsi\aditya139\adi\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\aditya kalsi\aditya139\adi\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\aditya kalsi\aditya139\adi\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\aditya kalsi\aditya139\adi\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\aditya kalsi\aditya139\adi\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\aditya kalsi\aditya139\adi\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.3.5)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\aditya kalsi\aditya139\adi\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.21.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\aditya kalsi\aditya139\adi\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\aditya kalsi\aditya139\adi\lib\site-packages (from jinja2->spacy) (2.1.3)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\users\aditya kalsi\aditya139\adi\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\aditya kalsi\aditya139\adi\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\aditya kalsi\aditya139\adi\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\aditya kalsi\aditya139\adi\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.0)
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ------------- -------------------------- 4.5/12.8 MB 22.4 MB/s eta 0:00:01
#      ------------------------------- ------- 10.2/12.8 MB 24.5 MB/s eta 0:00:01
#      --------------------------------------- 12.8/12.8 MB 21.7 MB/s eta 0:00:00
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install --upgrade numpy
# Out:
# Requirement already satisfied: numpy in c:\users\aditya kalsi\aditya139\adi\lib\site-packages (2.3.0)
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip uninstall -y h5py
# !pip install h5py
# Out:
# Found existing installation: h5py 3.14.0
# Uninstalling h5py-3.14.0:
#   Successfully uninstalled h5py-3.14.0
# Collecting h5py
#   Using cached h5py-3.14.0-cp311-cp311-win_amd64.whl.metadata (2.7 kB)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\aditya kalsi\aditya139\adi\lib\site-packages (from h5py) (2.3.0)
# Using cached h5py-3.14.0-cp311-cp311-win_amd64.whl (2.9 MB)
# Installing collected packages: h5py
# Successfully installed h5py-3.14.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-intel 2.16.1 requires numpy<2.0.0,>=1.23.5; python_version <= "3.11", but you have numpy 2.3.0 which is incompatible.
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import spacy.cli
spacy.cli.download("en_core_web_sm")
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy
import pandas as pd

nlp = spacy.load("en_core_web_sm")

def extract_keywords_spacy(feature_list):
    keywords = set()
    for item in feature_list:
        if isinstance(item, str):
            doc = nlp(item)
            # Extract noun chunks
            for chunk in doc.noun_chunks:
                text = chunk.text.strip().lower()
                if len(text) > 2 and not any(token.is_stop for token in chunk):
                    keywords.add(text.title())
            # Extract named entities (like Swiggy, Uber)
            for ent in doc.ents:
                if ent.label_ in ['ORG', 'PRODUCT', 'GPE']:
                    keywords.add(ent.text.strip().title())
            # Extract single important words (nouns/adjectives)
            for token in doc:
                if token.pos_ in ["NOUN", "PROPN", "ADJ"] and not token.is_stop:
                    keywords.add(token.lemma_.strip().title())
    return list(keywords)

# %%
df['refined_features'] = df['main_features'].apply(extract_keywords_spacy)

# %%
df['refined_features'][1]
# Out:
# ['Lessons',
#  'Merchants',
#  'Upto',
#  'Benefit',
#  '1% Cashback',
#  'Instamart',
#  'Cashback',
#  'Golf Services Insurance Benefits',
#  'Golf Services Insurance',
#  'Redemption',
#  'Swiggy One Membership Movie & Dining',
#  'Month',
#  'Credit Card Statement Travel',
#  'Services',
#  'Category',
#  'Card',
#  'Na Golf',
#  'Upto 5% Cashback',
#  'Uber',
#  'Rate',
#  'Complimentary',
#  'Credit',
#  'Travel',
#  'Domestic',
#  'Uber And Ola Domestic Lounge Access',
#  'Dineout',
#  'Golf',
#  'Na International Lounge Access',
#  'Swiggy App',
#  'Green Fees',
#  'Lounge',
#  '%',
#  '10% Cashback',
#  'Green',
#  'Free',
#  'Na',
#  'Statement',
#  'Food Orders',
#  'Membership',
#  'Online Spends',
#  'Order',
#  'Spend',
#  '5% Cashback',
#  'Ola Domestic Lounge Access',
#  'Ola',
#  '12 Free Golf Lessons',
#  'Rounds',
#  '4 Free Rounds',
#  'Reward',
#  'International',
#  'Swiggy',
#  'Insurance',
#  'Food',
#  'Online',
#  'Merchant',
#  'Dining',
#  'Movie',
#  'Fees',
#  'App',
#  'Access']

# %%
from spacy.lang.en.stop_words import STOP_WORDS
import re

# %%
def extract_keywords(text):
    if isinstance(text, list):
        text = ' '.join(text)
    
    text = clean_text(text)
    doc = nlp(text)
    keywords = set()

    for chunk in doc.noun_chunks:
        token = chunk.root.lemma_.lower()
        if token not in STOP_WORDS and token.isalpha() and len(token) > 2:
            keywords.add(token)

    for ent in doc.ents:
        ent_text = ent.text.lower()
        for word in ent_text.split():
            word = word.strip()
            if word not in STOP_WORDS and word.isalpha() and len(word) > 2:
                keywords.add(word)

    return list(keywords)

# %%
df['keywords'] = df['main_features'].apply(extract_keywords)

# %%
df['keywords'][19]
# Out:
# ['card',
#  'cashback',
#  'international',
#  'movie',
#  'annum',
#  'domestic',
#  'day',
#  'benefits',
#  'saturdays',
#  'restaurant',
#  'india',
#  'hour',
#  'redemption',
#  'days',
#  'dining',
#  'date',
#  'hours',
#  'food',
#  'offer',
#  'lounge',
#  'spending',
#  'misuse',
#  'access',
#  'city',
#  'golf',
#  'rewards',
#  'loss',
#  'buy',
#  'insurance',
#  'spends',
#  'time']

# %%
df['keywords_str'] = df['keywords'].apply(lambda x: ' '.join(x))

# %%
vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = vectorizer.fit_transform(df['keywords_str'])

# %%
def recommend_cards(user_input, top_n=5):
    """
    Recommends top N credit cards based on user input preferences.

    Parameters:
    - user_input: dict with keys:
        'max_joining_fee' (int),
        'max_renewal_fee' (int),
        'reward_preferences' (str),
        'welcome_bonus_preference' (bool)

    Returns:
    - DataFrame of top recommended cards with details
    """
    # Step 1: Filter by fee preferences
    filtered_df = df.copy()
    if 'max_joining_fee' in user_input:
        filtered_df = filtered_df[
            pd.to_numeric(filtered_df['Joining Fees Cleaned'], errors='coerce').fillna(0) <= user_input['max_joining_fee']
        ]
    if 'max_renewal_fee' in user_input:
        filtered_df = filtered_df[
            pd.to_numeric(filtered_df['Renewal Fees Cleaned'], errors='coerce').fillna(0) <= user_input['max_renewal_fee']
        ]

    if filtered_df.empty:
        return "No cards match your fee preferences."

    # Step 2: Vectorize user reward preferences
    user_query = user_input.get('reward_preferences', '')
    user_vector = vectorizer.transform([user_query])

    # Step 3: Compute similarity between user and card reward texts
    similarity_scores = cosine_similarity(user_vector, tfidf_matrix[filtered_df.index]).flatten()

    # Step 4: Boost cards that have a welcome bonus (based on USP column)
    if user_input.get('welcome_bonus_preference', False):
        bonus_boost = filtered_df['USP'].apply(lambda x: 0.1 if isinstance(x, str) and len(x) > 10 else 0)
        similarity_scores += bonus_boost.values

    # Step 5: Select top N recommendations
    top_indices = similarity_scores.argsort()[::-1][:top_n]
    recommendations = filtered_df.iloc[top_indices].copy()
    recommendations['Similarity Score'] = similarity_scores[top_indices]

    # Step 6: Return selected columns including benefits_text
    return recommendations[
        ['Card Name', 'Joining Fees', 'Renewal Fees', 'USP', 'Card Page Link', 'combined_features','Pros','Cons' ,'Similarity Score']
    ]

# %%
user_input = {
    'max_joining_fee': 5000,
    'max_renewal_fee': 999,
    'reward_preferences': 'travel  Zomato amazon Personal Accident Cover',
    'welcome_bonus_preference': True
}

# %%
df['combined_features'][6]
# Out:
# '₹2,000 Cashback on Making Four Transactions of ₹500 or Above Movie & Dining: BOGO on Movie Ticket Bookings Upto ₹400 With District by Zomato, Twice Each Month (Annual Benefit - ₹9,600) Rewards Rate: 10X Reward Points/₹150 on Incremental Spends Above ₹20,000 Per Statement Cycle. 5X Reward Points/₹150 on Spends Upto ₹20,000. 3X RPs Are Also Awarded for Rent, Wallet Load, Education, and Government Transactions Reward Redemption: Redeem for Vouchers/Cash Against Statement or Pay With Points. 1 RP = ₹0.25 Travel: 4 Complimentary Railway Lounge Access Each Quarter, 16 Each Year (For Both Primary and Add-On Cardholders) Domestic Lounge Access: 4 Complimentary Lounge Access Each Quarter International Lounge Access: 2 Complimentary Lounge Access Each Quarter Golf: 2 Free Golf Rounds/Lessons on Spends of ₹20,000 Each in a Statement Cycle Insurance Benefits: Purchase Protection, Personal Accident Cover, Free Trip Cancellation Protection, Travel Insurance and Credit Shield'

# %%
df['combined_features'][4]
# Out:
# 'Introductory Benefits Worth Rs. 600 on Card Issuance Movie & Dining: 15% Up to ₹500 Off at Partner Restaurants With Axis Bank Dining Delights Program Rewards Rate: 5% Cashback on Flipkart & Cleartrip, 4% Cashback on Preferred Partners (Swiggy, Uber, PVR, and cult.fit), and 1% Cashback on All Other Spends Travel: Accelerated Cashback (4%) on Uber Rides'

# %%
recommend_cards(user_input, top_n=5)
# Out:
#                             Card Name   Joining Fees   Renewal Fees  \
# 3   Amazon Pay ICICI Bank Credit Card  Lifetime Free  Lifetime Free
# 9           Axis Bank Neo Credit Card            Nil            Nil
# 8        Airtel Axis Bank Credit Card     ₹500 + GST     ₹500 + GST
# 10            AU Bank LIT Credit Card            Nil            Nil
# 13      IDFC FIRST Select Credit Card            Nil            Nil
#
#                                                   USP  \
# 3   Cashback and Discounts Up to ₹2,500 (Both for ...
# 9   100% Cashback Up to ₹300 on First Utility Bill...
# 8                        Amazon Voucher Worth Rs. 500
# 10
# 13  Vouchers worth ₹500 on spends of ₹5,000 within...
#
#                                        Card Page Link  \
# 3   https://cardinsider.com/icici-bank/amazon-pay-...
# 9   https://cardinsider.com/axis-bank/axis-bank-ne...
# 8   https://cardinsider.com/axis-bank/airtel-axis-...
# 10   https://cardinsider.com/au-bank/lit-credit-card/
# 13  https://cardinsider.com/idfc-first-bank/idfc-f...
#
#                                     combined_features  \
# 3   Cashback and Discounts Up to ₹2,500 (Both for ...
# 9   100% Cashback Up to ₹300 on First Utility Bill...
# 8   Amazon Voucher Worth Rs. 500 Movie & Dining: 1...
# 10   Movie & Dining: 3 Months of Complimentary Mem...
# 13  Vouchers worth ₹500 on spends of ₹5,000 within...
#
#                                                  Pros  \
# 3   This card is most useful to Amazon loyalist wh...
# 9   Get 10% off while booking movies with BookMySh...
# 8   You would get 25% exclusive cashback on Airtel...
# 10                                                NaN
# 13  This is a lifetime free credit card without an...
#
#                                                  Cons  Similarity Score
# 3   This card is mainly for shopping with Amazon i...          0.218761
# 9   There are no insurance benefits provided with ...          0.193643
# 8   With the Airtel Axis Bank Credit Card, you hav...          0.190931
# 10                                                NaN          0.173462
# 13  There isn’t any complimentary international lo...          0.167470
